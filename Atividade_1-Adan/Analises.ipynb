# %%
import pandas as pd

# %%
# Carregue os dados através da biblioteca Pandas ou Dask. 
df = pd.read_csv('forbes_billionaires_geo.csv')

# %%
# Exiba as 20 primeiras linhas do conjunto de dados selecionado.
df[:20]
# Out:
#                                      Name  NetWorth        Country  \
# 0                              Jeff Bezos     177.0  United States
# 1                               Elon Musk     151.0  United States
# 2                Bernard Arnault & family     150.0         France
# 3                              Bill Gates     124.0  United States
# 4                         Mark Zuckerberg      97.0  United States
# 5                          Warren Buffett      96.0  United States
# 6                           Larry Ellison      93.0  United States
# 7                              Larry Page      91.5  United States
# 8                             Sergey Brin      89.0  United States
# 9                           Mukesh Ambani      84.5          India
# 10                         Amancio Ortega      77.0          Spain
# 11  Francoise Bettencourt Meyers & family      73.6         France
# 12                         Zhong Shanshan      68.9          China
# ...

# %%
# Exiba o número de linhas de dados presentes no conjunto de dados selecionado.
df.shape
# Out:
# (2755, 13)

# %%
# Exiba a média, o desvio padrão, e os valores mínimo e máximo de um campo numérico do conjunto de dados selecionado.
df['Age'].describe()
# Out:
# count    2630.00000
# mean       63.26730
# std        13.47916
# min        18.00000
# 25%        54.00000
# 50%        63.00000
# 75%        73.00000
# max        99.00000
# Name: Age, dtype: float64

# %%
# Exiba as 5 primeiras linhas do conjunto de dados ordenado em ordem decrescente pelo mesmo campo numérico usado por você na questão 4.    
df.sort_values('Age', ascending=False)[:5]
# Out:
#                              Name  NetWorth        Country  \
# 1611                George Joseph       2.0  United States
# 1559                David Murdock       2.1  United States
# 729                 Masatoshi Ito       4.0          Japan
# 2273  Ana Maria Brescia Cafferata       1.3           Peru
# 1626               Charles Munger       2.0  United States
#
#                   Source  Rank   Age                Residence    Citizenship  \
# 1611           insurance  1580  99.0  Los Angeles, California  United States
# 1559   Dole, real estate  1517  98.0      Ventura, California  United States
# 729               retail   727  97.0             Tokyo, Japan          Japan
# 2273     mining, banking  2263  97.0               Lima, Peru           Peru
# 1626  Berkshire Hathaway  1580  97.0  Los Angeles, California  United States
#
#        Status  Children                                          Education  \
# ...
